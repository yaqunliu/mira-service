# %%
from app.utils.us3 import US3Client
# US3_PUBLIC_KEY=TOKEN_9945d4d8-08a6-41a5-b750-eaaa8208799c
# US3_PRIVATE_KEY=37f1a9ff-b856-4c98-8439-72065134a0da
# DOWNLOAD_SUFFIX=""
# UPLOAD_SUFFIX=""
# DEFAULT_BUCKET="novel-agent"
# US3_BUCKET="novel-agent"   
# US3_REGION="sh2"
us3_client = US3Client(
    public_key="TOKEN_a89563a9-48ea-4d2e-94e8-05561dc77e5a",
    private_key="d69e1507-422e-4347-a9d8-4950662f663f",
    upload_suffix=".cn-sh2.ufileos.com",
    download_suffix=".cn-sh2.ufileos.com",
    default_bucket="novel-agent",
)

resp = us3_client.upload_file(
    local_file="/Users/user/Documents/阴阳交错.txt",
    bucket="novel-agent",
    put_key="chapter/阴阳交错.txt"
)
print(resp)
# Out:
# 2025-11-26 15:06:28.955 | INFO     | app.utils.us3:__init__:73 - US3客户端初始化成功，上传后缀: .cn-sh2.ufileos.com, 下载后缀: .cn-sh2.ufileos.com
# 2025-11-26 15:06:28.962 | INFO     | app.utils.us3:upload_file:259 - 文件哈希值: fc79773ac4a7969aa25c272ca56ea033
# 2025-11-26 15:06:28.962 | INFO     | app.utils.us3:upload_file:261 - 开始上传文件: /Users/user/Documents/阴阳交错.txt -> novel-agent/chapter/阴阳交错.txt
# [2025-11-26 15:06:28,963, INFO]: filemanager.py-111: start put file /Users/user/Documents/阴阳交错.txt to bucket novel-agent as chapter/阴阳交错.txt
# [2025-11-26 15:06:28,964, INFO]: filemanager.py-112: put UFile url: http://novel-agent.cn-sh2.ufileos.com/chapter/阴阳交错.txt
# [2025-11-26 15:06:28,965, INFO]: filemanager.py-113: request header:
# {
#     "User-Agent": "UCloud UFile Python SDK 3.2.11 (Darwin: arm64 : Python/3.10.19)",
#     "Content-Type": "text/plain",
#     "Authorization": "UCloud TOKEN_a89563a9-48ea-4d2e-94e8-05561dc77e5a:yDGsD40jaGj/JLmZp7ZL8hYGHiQ=",
#     "Content-Length": "944415"
# }
# ...
