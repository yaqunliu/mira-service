# %%
cmd = ['ffmpeg', '-y', 
       '-i', '/Users/user/code/mira-service/static/video.mp4', 
       '-i', '/Users/user/code/mira-service/static/audio.mp3',  # 音频文件
       '-vf', "subtitles='/Users/user/code/mira-service/static/subtitle.srt'", 
       '-c:v', 'libx264', '-preset', 'veryfast', '-crf', '23', 
       '-c:a', 'aac', '-b:a', '192k', '-shortest', 
       'out_test.mp4']
from re import sub
import subprocess
subprocess.Popen(cmd)
# Out:
# <Popen: returncode: None args: ['ffmpeg', '-y', '-i', '/Users/user/code/mira...>
# ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.6)
# ...

# %%
voices.items
