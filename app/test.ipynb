# %%
try:
       raise Exception("test")
except Exception as e:
       print(e)
       print(type(e).__name__)
       print(str(e))
# Out:
# test
# Exception
# test

# %%
text = """ Anime style, ancient Chinese restaurant hall "Tianxia Di Yi Lou" first floor – a spacious chamber approximately fifty paces square, featuring four round rosewood tables, bamboo chairs, hanging paper lanterns casting warm glows, ornate carved screens, and a central counter where an accountant stands observing. The environment radiates rich historical authenticity with soft, diffused lighting enhancing wooden textures and fabric drapes. White Yu-Tang (oval face, fair skin, phoenix eyes, black pupils, willow eyebrows, tall slender figure) stands proudly with hands raised in a "V for victory" gesture, head high, long black hair flowing down to her waist loosely tied with loose strands framing her face, wearing a米white blazer, light blue shirt, yellow gauze skirt, heels, no accessories. Ruo Huang slams the table laughing, body leaning backward in amusement; Ruo Mei leans forward urgently, hands tightly gripping the table edge, eyes wide with curiosity. The trio forms a dynamic triangular composition amid lively interaction, capturing emotional intensity and character chemistry. Warm ambient light from lanterns creates gentle shadows and highlights, enhancing depth and realism. Cinematic anime aesthetic, detailed background, 8k, masterpiece, strictly preserve reference face and hairstyle"""

splits = text.split(" ")

print(len(splits))
# Out:
# 187
